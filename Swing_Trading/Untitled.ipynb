# %%
import os
import csv
from natsort import natsorted
import pandas as pd
import datetime
import numpy as np
data = list
a = pd.DataFrame()
for file in natsorted(os.listdir('csvs/csv1/')):
    # with open(os.path.join(os.getcwd(),'csvs', file), 'r') as read_file:
    #     csv_file = csv.reader(read_file)
    #     d = dict(filter(None, csv_file))
    #     print(d)
    df = pd.read_csv(os.path.join(os.getcwd(),'csvs/csv1/', file))
#     df = df[df['SERIES'] == 'EQ']
   
    x = df[df['SERIES'] == 'EQ']
#     x = df[df['SYMBOL'] == '3PLAND']
#     print(type(x))
    a = a.append(x)
for stocks in x['SYMBOL']:
    print(stocks)
    new_data = pd.DataFrame()
    for file in natsorted(os.listdir('csvs/csv1/')):
        df = pd.read_csv(os.path.join(os.getcwd(),'csvs/csv1/', file))
    #     new_a = pd.DataFrame()
        x = df[df['SYMBOL'] == stocks]
        new_data.append(x)
    print(new_data)
    new_data.to_csv(os.path.join(os.getcwd(),'stock_csv', f'{stocks}.csv'))
# Out:
# 20MICRONS
# Empty DataFrame
# Columns: []
# Index: []
# 21STCENMGM
# Empty DataFrame
# Columns: []
# Index: []
# 3IINFOLTD
# Empty DataFrame
# Columns: []
# Index: []
# 3MINDIA
# Empty DataFrame
# Columns: []
# Index: []
# 5PAISA
# Empty DataFrame
# Columns: []
# Index: []
# A2ZINFRA
# Empty DataFrame
# Columns: []
# Index: []
# AAKASH
# Empty DataFrame
# Columns: []
# Index: []
# AAREYDRUGS
# Empty DataFrame
# Columns: []
# Index: []
# AARON
# Empty DataFrame
# Columns: []
# Index: []
# AARTIDRUGS
# Empty DataFrame
# Columns: []
# Index: []
# AARTIIND
# Empty DataFrame
# Columns: []
# Index: []
# AARTISURF
# Empty DataFrame
# Columns: []
# Index: []
# AARVEEDEN
# Empty DataFrame
# Columns: []
# Index: []
# AARVI
# Empty DataFrame
# Columns: []
# Index: []
# AAVAS
# Empty DataFrame
# Columns: []
# Index: []
# ABAN
# Empty DataFrame
# Columns: []
# Index: []
# ABB
# Empty DataFrame
# Columns: []
# Index: []
# ABBOTINDIA
# Empty DataFrame
# Columns: []
# Index: []
# ABCAPITAL
# ...

# %%
a
# Out:
#    SYMBOL SERIES   OPEN   HIGH    LOW  CLOSE   LAST  PREVCLOSE  TOTTRDQTY  \
# 5  3PLAND     EQ   8.55   8.55   8.55   8.55   8.55       8.15      14085
# 4  3PLAND     EQ   8.95   8.95   8.95   8.95   8.95       8.55       6530
# 4  3PLAND     EQ   9.35   9.35   8.95   9.35   9.35       8.95       7463
# 4  3PLAND     EQ   9.80   9.80   9.00   9.80   9.80       9.35       5793
# 4  3PLAND     EQ  10.25  10.25  10.25  10.25  10.25       9.80       3717
# 4  3PLAND     EQ  10.75  10.75  10.75  10.75  10.75      10.25       5720
# 4  3PLAND     EQ  11.25  11.25  11.25  11.25  11.25      10.75       6051
# 4  3PLAND     EQ  11.80  11.80  11.80  11.80  11.80      11.25       9408
# 5  3PLAND     EQ  12.35  12.35  12.35  12.35  12.35      11.80       8147
# 6  3PLAND     EQ  12.95  12.95  12.95  12.95  12.95      12.35      12050
# 5  3PLAND     EQ  13.55  13.55  12.35  12.35  12.35      12.95      12423
# 5  3PLAND     EQ  11.75  11.75  11.75  11.75  11.75      12.35       5397
# ...

# %%
import mplfinance as mpf
import os
import pandas as pd
for csv in os.listdir('stock_csv/Feb/'):
    print(csv)
    a = pd.read_csv(os.path.join(os.getcwd(), 'stock_csv/Feb/', csv))
    x = a[['TIMESTAMP', 'OPEN', 'HIGH', 'LOW', 'CLOSE', 'PREVCLOSE', 'TOTTRDVAL']]
    x['TIMESTAMP'] = pd.to_datetime(x['TIMESTAMP'])
    x.columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']
    x = x.set_index('Date')
    x['MA20'] = x['close'].rolling(window=20).mean()
    x['20dSTD'] = x['close'].rolling(window=20).std()

    x['Upper'] = x['MA20'] + (x['20dSTD'] * 2)
    x['Lower'] = x['MA20'] - (x['20dSTD'] * 2)

    filename = os.path.join(os.getcwd(), 'stock_image/Feb/', csv.split('.')[0] + '.png')
    mpf.plot(x, type='candle', volume=True, savefig=filename)
# Out:
# 20MICRONS.csv
# C:\ProgramData\Anaconda3\envs\swing-bot\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 21STCENMGM.csv
# C:\ProgramData\Anaconda3\envs\swing-bot\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 3IINFOLTD.csv
# C:\ProgramData\Anaconda3\envs\swing-bot\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
x
# Out:
#              Open   High    Low  Close  Adj Close     Volume
# Date
# 2020-12-01   8.55   8.55   8.55   8.55       8.15  120426.75
# 2020-12-02   8.95   8.95   8.95   8.95       8.55   58443.50
# 2020-12-03   9.35   9.35   8.95   9.35       8.95   69514.85
# 2020-12-04   9.80   9.80   9.00   9.80       9.35   56317.95
# 2020-12-07  10.25  10.25  10.25  10.25       9.80   38099.25
# 2020-12-08  10.75  10.75  10.75  10.75      10.25   61490.00
# 2020-12-09  11.25  11.25  11.25  11.25      10.75   68073.75
# 2020-12-10  11.80  11.80  11.80  11.80      11.25  111014.40
# 2020-12-11  12.35  12.35  12.35  12.35      11.80  100615.45
# 2020-12-14  12.95  12.95  12.95  12.95      12.35  156047.50
# 2020-12-15  13.55  13.55  12.35  12.35      12.95  158587.40
# 2020-12-16  11.75  11.75  11.75  11.75      12.35   63414.75
# 2020-12-17  11.20  11.20  11.20  11.20      11.75   44027.20
# 2020-12-18  10.65  10.65  10.65  10.65      11.20    9829.95
# ...

# %%
import mplfinance as mpf

mpf.plot(x, type= 'line', volume= True)
